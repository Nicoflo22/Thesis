# %% [markdown]
# # Imports

# %%
#import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
import os
import wfdb
from scipy import signal
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
#from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import neurokit2 as nk
from sklearn.preprocessing import MinMaxScaler
from scipy.signal import butter, lfilter, freqz, iirnotch

import tensorflow as tf
from tensorflow.keras import layers

# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.expand_frame_repr', False)  # Disable wrapping
# pd.set_option('display.max_colwidth', None)  # Show full contents of each cell

pd.reset_option('display.max_columns')  # Show all columns
pd.reset_option('display.expand_frame_repr')  # Disable wrapping
pd.reset_option('display.max_colwidth')  # Show full contents of each cell

# %% [markdown]
# # Load data

# %%
# import os
# import pandas as pd
# import wfdb

# # Load the CSV file
# superclass_df = pd.read_csv('superclass.csv')

# # Initialize empty arrays to store the data
# data = []

# # Specify the root directory
# root_dir = '../ptb-xl/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'

# # Loop over all records in the DataFrame
# for idx, row in superclass_df.iterrows():
#     if (idx+1)%100 == 0:
#         print(f"Processing record {idx+1}/{len(superclass_df)}")
#     # Get filename without extension
#     filename = os.path.splitext(row['filename_lr'])[0]

#     # Construct the full path
#     full_path = os.path.join(root_dir, filename)

#     # Load the raw ECG signal data from the .dat file
#     dat, fields = wfdb.rdsamp(full_path)

#     # Load the labels data from the .hea file
#     hea = wfdb.rdheader(full_path)

#     # Add data to the list
#     data.append({
#         'record_name': filename,
#         'superclass': row['diagnostic_superclass'],
#         'signal': dat,
#         'age': row['age'],
#         'sex': row['sex']
#     })

# # Convert the list to a DataFrame
# df = pd.DataFrame(data)

# # Save the DataFrame
# df.to_pickle('df_processed.pkl')

df_orig = pd.read_pickle('C:/Users/nicol/Downloads/df_processed_250.pkl')
df_orig
# Out:
#                      record_name superclass  \
# 0      records500/00000/00001_hr   ['NORM']
# 1      records500/00000/00002_hr   ['NORM']
# 2      records500/00000/00003_hr   ['NORM']
# 3      records500/00000/00004_hr   ['NORM']
# 4      records500/00000/00005_hr   ['NORM']
# ...                          ...        ...
# 16239  records500/21000/21833_hr   ['STTC']
# 16240  records500/21000/21834_hr   ['NORM']
# 16241  records500/21000/21835_hr   ['STTC']
# 16242  records500/21000/21836_hr   ['NORM']
# 16243  records500/21000/21837_hr   ['NORM']
#
#                                                   signal    age  sex
# 0      [[-0.08588371897207263, -0.03736346853162483, ...   56.0    1
# 1      [[-0.011243299508205044, 0.09023407534582495, ...   19.0    0
# 2      [[-0.02596508144425195, -0.052584897690685514,...   37.0    1
# 3      [[-0.04137347387754445, -0.11622565135690588, ...   24.0    0
# 4      [[-0.03003880948325483, -0.43121334841072106, ...   19.0    1
# ...                                                  ...    ...  ...
# 16239  [[-0.04391078902957227, -0.02257351658386932, ...   67.0    1
# 16240  [[-0.026419722051677138, 0.0036079393377764384...  300.0    0
# 16241  [[0.06267955458986217, 0.0552252383461329, -0....   59.0    1
# 16242  [[-0.03373067418018933, -0.02617115333028704, ...   64.0    1
# 16243  [[-0.03745155669436234, -0.022392895272037833,...   68.0    0
#
# [16244 rows x 5 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## downsampling NORM class

# %%
# # Filter out the "NORM" class

# norm_df = df_orig[df_orig['superclass'] == '[\'NORM\']']

# # Randomly sample 6000 records from the "NORM" class to be removed
# to_remove = norm_df.sample(6000, random_state=1)

# # Remove these from the original df
# df = df_orig.drop(to_remove.index)
# df = df.reset_index(drop=True)

# df
df = df_orig

# %% [markdown]
# ## One Hot

# %%
# Make sure each label is in a separate list
df['superclass'] = df['superclass'].apply(lambda x: [x] if isinstance(x, str) else x)

mlb = MultiLabelBinarizer()
label_encoded = mlb.fit_transform(df['superclass'])
df_encoded = pd.concat([df.drop('superclass', axis=1), pd.DataFrame(label_encoded, columns=mlb.classes_)], axis=1)

df_encoded
# Out:
#                      record_name  \
# 0      records500/00000/00001_hr
# 1      records500/00000/00002_hr
# 2      records500/00000/00003_hr
# 3      records500/00000/00004_hr
# 4      records500/00000/00005_hr
# ...                          ...
# 16239  records500/21000/21833_hr
# 16240  records500/21000/21834_hr
# 16241  records500/21000/21835_hr
# 16242  records500/21000/21836_hr
# 16243  records500/21000/21837_hr
#
#                                                   signal    age  sex  ['CD']  \
# 0      [[-0.08588371897207263, -0.03736346853162483, ...   56.0    1       0
# 1      [[-0.011243299508205044, 0.09023407534582495, ...   19.0    0       0
# 2      [[-0.02596508144425195, -0.052584897690685514,...   37.0    1       0
# 3      [[-0.04137347387754445, -0.11622565135690588, ...   24.0    0       0
# 4      [[-0.03003880948325483, -0.43121334841072106, ...   19.0    1       0
# ...                                                  ...    ...  ...     ...
# 16239  [[-0.04391078902957227, -0.02257351658386932, ...   67.0    1       0
# 16240  [[-0.026419722051677138, 0.0036079393377764384...  300.0    0       0
# 16241  [[0.06267955458986217, 0.0552252383461329, -0....   59.0    1       0
# 16242  [[-0.03373067418018933, -0.02617115333028704, ...   64.0    1       0
# 16243  [[-0.03745155669436234, -0.022392895272037833,...   68.0    0       0
#
#        ['HYP']  ['MI']  ['NORM']  ['STTC']
# 0            0       0         1         0
# 1            0       0         1         0
# 2            0       0         1         0
# 3            0       0         1         0
# 4            0       0         1         0
# ...        ...     ...       ...       ...
# 16239        0       0         0         1
# 16240        0       0         1         0
# 16241        0       0         0         1
# 16242        0       0         1         0
# 16243        0       0         1         0
#
# [16244 rows x 9 columns]

# %% [markdown]
# SPLIT

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Separate the target labels (heart condition classes) and the input features
X_ecg = np.array(df_encoded['signal'].tolist())
X_info = df_encoded[[]]  # age and sex as additional features
y = df_encoded.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

# Split the data into training, validation, and test sets
X_ecg_train, X_ecg_test, X_info_train, X_info_test, y_train, y_test = train_test_split(
    X_ecg, X_info, y, test_size=0.3, random_state=12
)
X_ecg_val, X_ecg_test, X_info_val, X_info_test, y_val, y_test = train_test_split(
    X_ecg_test, X_info_test, y_test, test_size=0.5, random_state=12
)

# Apply feature scaling (if needed) on the ECG signal data
# scaler = StandardScaler()
# X_ecg_train = np.array([scaler.fit_transform(sample) for sample in X_ecg_train])
# X_ecg_val = np.array([scaler.transform(sample) for sample in X_ecg_val])
# X_ecg_test = np.array([scaler.transform(sample) for sample in X_ecg_test])

# Check the shapes of the datasets
print("ECG Data Shapes:")
print("Training data:", X_ecg_train.shape)
print("Validation data:", X_ecg_val.shape)
print("Test data:", X_ecg_test.shape)
print("\nInfo Data Shapes:")
print("Training data:", X_info_train.shape)
print("Validation data:", X_info_val.shape)
print("Test data:", X_info_test.shape)
print("\nTarget Labels Shape:")
print("Training labels:", y_train.shape)
print("Validation labels:", y_val.shape)
print("Test labels:", y_test.shape)
# Out:
# ECG Data Shapes:
# Training data: (11370, 2500, 12)
# Validation data: (2437, 2500, 12)
# Test data: (2437, 2500, 12)
#
# Info Data Shapes:
# Training data: (11370, 0)
# Validation data: (2437, 0)
# Test data: (2437, 0)
#
# Target Labels Shape:
# Training labels: (11370, 5)
# Validation labels: (2437, 5)
# Test labels: (2437, 5)

# %% [markdown]
# ## Upsample lowest class

# %%
# import numpy as np
# from sklearn.utils import resample

# # Get column names
# class_labels = y_train.columns

# # Get index of the max value in each row (which will be 1 in one-hot encoding)
# label_indices = np.argmax(y_train.values, axis=1)

# # Map the index to the corresponding class label
# y_train_single_column = np.array([class_labels[idx] for idx in label_indices])

# # Now create train_df
# train_df = pd.DataFrame({'signal': [signal for signal in X_ecg_train], 'superclass': y_train_single_column})


# def add_noise(data, noise_factor=0.01):
#     noise = np.random.normal(size=data.shape)
#     augmented_data = data + noise_factor * noise
#     return augmented_data

# # Separate the 'HYP' class
# hyp_df = train_df[train_df['superclass'] == '[\'HYP\']']

# # Determine how many instances you need to resample
# n_samples = 1000  # adjust this value as needed

# # Resample the 'HYP' class
# hyp_upsampled = resample(hyp_df,
#                          replace=True,  # sample with replacement
#                          n_samples=n_samples,  # to match number in majority class
#                          random_state=1)  # reproducible results

# # Add noise to the resampled 'HYP' data
# # Assuming 'ecg_data' column contains the ECG data

# hyp_upsampled['signal'] = hyp_upsampled['signal'].apply(add_noise)


# # Create labels for 'HYP' class
# hyp_label = np.zeros(len(class_labels))
# hyp_label[class_labels.get_loc('[\'HYP\']')] = 1  # Assuming 'HYP' is one of the labels

# # Count of original 'HYP' instances
# original_hyp_count = len(hyp_df)

# # Resample and add noise to the 'HYP' class
# hyp_upsampled = resample(hyp_df, replace=True, n_samples=n_samples, random_state=1)
# hyp_upsampled['signal'] = hyp_upsampled['signal'].apply(add_noise)

# # Calculate how many new 'HYP' instances have been created
# new_hyp_count = len(hyp_upsampled) - original_hyp_count

# # Create corresponding labels for the new 'HYP' instances
# new_hyp_labels = np.repeat([hyp_label], new_hyp_count, axis=0)

# # Add new 'HYP' labels to y_train
# y_train = np.vstack((y_train, new_hyp_labels))

# # Combine the upsampled 'HYP' class with the rest of the training data
# train_df = pd.concat([train_df[train_df['superclass'] != '[\'HYP\']'], hyp_upsampled])
# train_df = train_df.reset_index(drop=True)

# # Transform 'train_df' back into your training dataset 'X_ecg_train'
# X_ecg_train = np.stack(train_df['signal'].values)



# # Choose one signal from the upsampled dataframe
# original_signal = hyp_upsampled['signal'].iloc[0]

# # Apply noise to this signal
# noisy_signal = add_noise(original_signal)

# # Plot original signal (first lead)
# plt.figure(figsize=(15, 3))
# plt.plot(original_signal[:, 0])  # select the first lead
# plt.title("Original ECG Signal (Lead 1)")
# plt.show()

# # Plot noisy signal (first lead)
# plt.figure(figsize=(15, 3))
# plt.plot(noisy_signal[:, 0])  # select the first lead
# plt.title("Noisy ECG Signal (Lead 1)")
# plt.show()

# %% [markdown]
# ## Distribution of diseases SNOMED

# %%
# plt.figure(figsize=(10, 6))

# # Bar chart
# bars = plt.bar(disease_counts_sorted.index.astype(str), disease_counts_sorted.values)

# # Add data values to the top of the bars
# for bar in bars:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

# plt.xlabel('SNOMED Disease Code')
# plt.ylabel('Number of Patients')
# plt.title('Distribution of Diseases')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## test display

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 8))

# Create a list to store all ECG signals
all_ecgs = []

# Iterate over the 12 leads
for i in range(12):
    single_ecg = []
    for sublist in df_encoded.loc[3,'signal']:  # Get the data for one patient
        single_ecg.append(sublist[i])  # Get data for one lead

    signals, info = nk.ecg_process(single_ecg, sampling_rate=100)
    cleaned_ecg = signals["ECG_Clean"]

    all_ecgs.append(cleaned_ecg)

# Combine all ECG signals into a single 2D array
all_ecgs = np.stack(all_ecgs)

# Plot each ECG lead with a slight vertical shift for better visibility
for i, ecg in enumerate(all_ecgs):
    plt.plot(ecg + i*2)  # Shift each lead by 200 units

plt.title('ECG signals for all 12 leads')
plt.show()

# %% [markdown]
# ## Remove last beat if incomplete

# %%
# cpt=0
# def clean_heartbeats(row):
#     global cpt
#     all_leads = []
#     for sublist in row['signal']:
#         all_leads.append(sublist)  # Get all leads

#     # Process lead II to get R-peaks
#     single_ecg_lead_II = [sublist[1] for sublist in row['signal']]  # LEAD II
#     try:
#         signals, info = nk.ecg_process(single_ecg_lead_II, sampling_rate=100)
#     except ValueError as e:
#         print(f"An error occurred while processing the ECG data for record {row['record_name']}: {e}")
#         return single_ecg_lead_II  # Return the original ECG signal if an error occurs

#     rpeaks = info["ECG_R_Peaks"]
#     # Remove NaN values from rpeaks
#     rpeaks = rpeaks[~np.isnan(rpeaks)]
#     try:
#         heartbeats_II = np.split(single_ecg_lead_II, rpeaks.astype(int))
#     except ValueError as e:
#         print(f"An error occurred while splitting the ECG data for record {row['record_name']}: {e}")
#         return single_ecg_lead_II  # Return the original ECG signal if an error occurs

#     # Check if the last heartbeat is incomplete (i.e., significantly shorter than the others)
#     average_heartbeat_length = np.mean([len(heartbeat) for heartbeat in heartbeats_II])
#     if len(heartbeats_II[-1]) < average_heartbeat_length * 0.75:
#         rpeaks = rpeaks[:-1]  # Remove the last R-peak
#         cpt += 1

#     # Use the R-peaks to segment all leads and remove incomplete heartbeats
#     cleaned_ecg_leads = []
#     for lead in all_leads:
#         try:
#             heartbeats = np.split(lead, rpeaks.astype(int))
#         except ValueError as e:
#             print(f"An error occurred while splitting the ECG data for record {row['record_name']}: {e}")
#             return lead  # Return the original ECG signal if an error occurs

#         if len(heartbeats[-1]) < average_heartbeat_length * 0.75:
#             heartbeats = heartbeats[:-1]  # Remove the last heartbeat if incomplete
#         # Concatenate the heartbeats back into a single ECG signal
#         cleaned_ecg_lead = np.concatenate(heartbeats)
#         cleaned_ecg_leads.append(cleaned_ecg_lead)

#     # Stack the cleaned leads back together
#     cleaned_ecg = np.stack(cleaned_ecg_leads, axis=-1)
#     return cleaned_ecg


# # Apply the function to the 'signal' column of the DataFrame
# df_encoded_removed_beats = df_encoded
# df_encoded_removed_beats['signal'] = df_encoded.apply(clean_heartbeats, axis=1)
# print(df_encoded_removed_beats)
# print(df_encoded_removed_beats['signal'][0])
# print(df_encoded_removed_beats['signal'][0][0])
# print(df_encoded_removed_beats['signal'][0][0][0])
# print(df_encoded_removed_beats.shape)
# print(f"number of incomplete beats patients: {cpt}/{len(df_encoded.index)}")
# df_encoded_removed_beats.to_pickle('df_encoded_removed_beats.pkl')

# %% [markdown]
# ## Notch filer - 50hz cleaning

# %%
# # Define the sample rate and the frequencies for the notch and low-pass filters
# sample_rate = 100
# notch_freq = 50
# low_pass_freq = 15  # Adjust the low-pass frequency to maintain similar filtering characteristics

# def design_filters(sample_rate, notch_freq, low_pass_freq):
#     # Design the notch filter
#     nyquist = 0.5 * sample_rate
#     freq_ratio = notch_freq / nyquist
#     notch_filter = iirnotch(freq_ratio, 30)  # 30 is the quality factor of the filter

#     # Design the low-pass filter
#     low_pass_filter = butter(5, low_pass_freq / nyquist, btype='low')

#     return notch_filter, low_pass_filter

# # Design the filters
# notch_filter, low_pass_filter = design_filters(sample_rate, notch_freq, low_pass_freq)
# # Define a function to apply the filters
# def apply_filters(data, notch_filter, low_pass_filter):
#     # Apply the notch filter
#     data = lfilter(*notch_filter, data)

#     # Apply the low-pass filter
#     data = lfilter(*low_pass_filter, data)

#     return data
# # Apply the filters to the data
# print(df_encoded.shape)
# df_encoded['signal'] = df_encoded['signal'].apply(lambda signal: apply_filters(signal, notch_filter, low_pass_filter))
# print(df_encoded.shape)

# %% [markdown]
# ## Smoothen signal cleaning

# %%
# # def moving_average(signal, window_size):
# #     # If the signal has more than one channel, apply the moving average to each channel
# #     if signal.ndim > 1:
# #         return np.array([np.convolve(channel, np.ones(window_size) / window_size, mode='same') for channel in signal.T]).T
# #     # If the signal is only one channel, apply the moving average normally
# #     else:
# #         return np.convolve(signal, np.ones(window_size) / window_size, mode='same')

# # df_encoded['signal'] = df_encoded['signal'].apply(lambda signal: moving_average(signal, window_size=3))

# # df_encoded['signal'] = df_encoded['signal'].apply(lambda signal: butter_lowpass_filter(signal, cutoff, fs, order))

# import pywt
# from scipy.stats import median_abs_deviation as mad

# def maddest(d, axis=None):  # Mean Absolute Deviation
#     return np.mean(np.absolute(d - np.mean(d, axis)), axis)

# def wavelet_smooth(signal, wavelet="db5", level=1):
#     coeff = pywt.wavedec(signal, wavelet, mode="per")
#     sigma = (1/0.6745) * maddest(coeff[-level])
#     uthresh = sigma * np.sqrt(2*np.log(len(signal)))
#     coeff[1:] = (pywt.threshold(i, value=uthresh, mode="soft") for i in coeff[1:])
#     reconstructed_signal = pywt.waverec(coeff, wavelet, mode="per")
#     return reconstructed_signal

# df_encoded['signal'] = df_encoded['signal'].apply(lambda signal: wavelet_smooth(signal))

# %% [markdown]
# ## Remove Outliers

# %%
# # Compute the mean and standard deviation for each record
# means = np.array([np.mean(record) for record in df_encoded['signal']])
# std_devs = np.array([np.std(record) for record in df_encoded['signal']])

# # Compute the average mean and standard deviation
# avg_mean = np.mean(means)
# avg_std_dev = np.mean(std_devs)

# # Compute the standard deviation of the means and standard deviations
# std_mean = np.std(means)
# std_std_dev = np.std(std_devs)

# # Identify outliers as records where the mean or standard deviation is more than 3 standard deviations from the average
# outlier_indices = np.where(
#     (np.abs(means - avg_mean) > 3 * std_mean) |
#     (np.abs(std_devs - avg_std_dev) > 3 * std_std_dev)
# )[0]

# # Remove outliers from df
# df_cleaned = df_encoded.drop(outlier_indices)
# print(df_cleaned.shape)
# print(len(df_cleaned['signal'][0]))
# print(df_cleaned['signal'][0][0])
# #df_cleaned = df_encoded

# %% [markdown]
# ## Normalization

# %%
# from tqdm import tqdm

# def normalize_patient_signals(patient_signals, patient_index):
#     scaler = MinMaxScaler(feature_range=(-1, 1))
#     patient_ecgs_normalized = []

#     for i in range(12):
#         single_ecg = patient_signals[:, i]

#         try:
#             signals, info = nk.ecg_process(single_ecg, sampling_rate=100)
#             cleaned_ecg = signals["ECG_Clean"]

#             # Normalize the ECG signal
#             normalized_ecg = scaler.fit_transform(cleaned_ecg.to_numpy().reshape(-1, 1))

#             # Center the normalized ECG signal around 0
#             normalized_centered_ecg = normalized_ecg - np.mean(normalized_ecg)
#             patient_ecgs_normalized.append(normalized_centered_ecg.flatten())

#         except ValueError:
#             print(f"Error processing ECG signal for patient at index {patient_index}. Plotting signal and skipping...")
#             plt.figure(figsize=(10, 4))
#             plt.plot(single_ecg)
#             plt.title(f'ECG signal causing error for patient at index {patient_index}')
#             plt.show()
#             return None  # Return None to indicate an error

#     # Combine all normalized ECG signals for current patient into a single 2D array
#     return np.stack(patient_ecgs_normalized)


# # Apply the function to each row in the 'signal' column, and also pass the index to the function
# for index in tqdm(df_encoded.index):
#     df_encoded.at[index, 'signal'] = normalize_patient_signals(df_encoded.loc[index, 'signal'], index)

# # Drop rows where 'signal' is None (i.e., the ECG processing failed)
# df_encoded = df_encoded.dropna(subset=['signal'])


# df_cleaned = df_encoded

# %%
# def minmax_scale_image(image):
#     min_val = image.min()
#     max_val = image.max()
#     scaled_image = (image - min_val) / (max_val - min_val)
#     return scaled_image

# # Apply the minmax_scale_image function to each 2D image in the 'signal' column
# df_encoded['signal'] = df_encoded['signal'].apply(minmax_scale_image)

# %% [markdown]
# Random Forest Test

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier

# # Flatten the data
# X_ecg_train_flattened = X_ecg_train.reshape(X_ecg_train.shape[0], -1)
# X_ecg_val_flattened = X_ecg_val.reshape(X_ecg_val.shape[0], -1)
# X_ecg_test_flattened = X_ecg_test.reshape(X_ecg_test.shape[0], -1)

# # Convert DataFrames to NumPy arrays and then to label-encoded form
# y_train_single = np.argmax(y_train.values, axis=1)
# y_val_single = np.argmax(y_val.values, axis=1)
# y_test_single = np.argmax(y_test.values, axis=1)

# # Define the parameter grid
# param_grid = {
#     'n_estimators': [100, 200],
#     'max_depth': [None, 20],
#     'min_samples_split': [2, 5],
#     'min_samples_leaf': [1, 2],
#     'max_features': ['auto']
# }

# # Create a base model
# rf = RandomForestClassifier(random_state=12)

# # Instantiate the grid search model
# grid_search = GridSearchCV(estimator = rf, param_grid = param_grid,
#                            cv = 2, n_jobs = -1, verbose = 2)

# # Fit the grid search to the data
# grid_search.fit(X_ecg_train_flattened, y_train_single)

# # Print the best parameters
# print(grid_search.best_params_)

# # Use the best model
# best_grid = grid_search.best_estimator_

# # Make predictions using the best model
# y_val_pred = best_grid.predict(X_ecg_val_flattened)

# %% [markdown]
# # CNN

# %% [markdown]
# ## 10-Fold

# %%
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt

X = df_encoded['signal'].to_numpy()
X = np.array([np.array(x) for x in df_encoded['signal']])

y = df_encoded.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

n_folds = 10
kfold = KFold(n_splits=n_folds, shuffle=True, random_state=42)
scores = []

for train_index, val_index in kfold.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Define the ECG branch of the model
    ecg_input = layers.Input(shape=(2500, 12))
    ecg_layer = layers.Conv1D(64, 7, activation='relu')(ecg_input)
    ecg_layer = layers.MaxPooling1D(3)(ecg_layer)
    ecg_layer = layers.Conv1D(64, 7, activation='relu')(ecg_layer)
    ecg_layer = layers.MaxPooling1D(3)(ecg_layer)
    ecg_layer = layers.Dropout(0.5)(ecg_layer)
    ecg_layer = layers.Flatten()(ecg_layer)


    # Add a couple of Dense layers
    output = layers.Dense(64, activation='relu')(ecg_layer)
    output = layers.Dropout(0.5)(output)
    output = layers.Dense(y_train.shape[1], activation='softmax')(output)

    model_cnn = tf.keras.Model(inputs=[ecg_input], outputs=output)
    model_cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model_cnn.fit(X_train, y_train, epochs=10)
    score = model_cnn.evaluate(X_val, y_val)  # Set verbose=0 to not print evaluation results
    scores.append(score)

scores = np.array(scores)
mean_score = np.mean(scores[:, 1])
std_score = np.std(scores[:, 1])

# Compute the 95% confidence interval
confidence_interval = 1.96 * (std_score / np.sqrt(n_folds))
lower_bound = mean_score - confidence_interval
upper_bound = mean_score + confidence_interval

print(f'Mean validation accuracy over {n_folds}-fold cross-validation: {mean_score * 100:.2f}%')
print(f'Standard deviation: {std_score * 100:.2f}%')
print(f'95% confidence interval: ({lower_bound * 100:.2f}%, {upper_bound * 100:.2f}%)')

plt.hist(scores[:, 1], bins=10)
plt.title(f'Histogram of validation accuracy over {n_folds}-fold cross-validation')
plt.xlabel('Validation Accuracy')
plt.ylabel('Count')
plt.show()
# Out:
# Epoch 1/10
# 457/457 [==============================] - 32s 68ms/step - loss: 1.0368 - categorical_accuracy: 0.6392
# Epoch 2/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.8235 - categorical_accuracy: 0.7212
# Epoch 3/10
# 457/457 [==============================] - 32s 69ms/step - loss: 0.7256 - categorical_accuracy: 0.7571
# Epoch 4/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.6654 - categorical_accuracy: 0.7694
# Epoch 5/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6224 - categorical_accuracy: 0.7850
# Epoch 6/10
# 457/457 [==============================] - 53s 116ms/step - loss: 0.5728 - categorical_accuracy: 0.7970
# Epoch 7/10
# 457/457 [==============================] - 52s 113ms/step - loss: 0.5379 - categorical_accuracy: 0.8083
# Epoch 8/10
# 457/457 [==============================] - 49s 108ms/step - loss: 0.5038 - categorical_accuracy: 0.8171
# Epoch 9/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.4749 - categorical_accuracy: 0.8252
# Epoch 10/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.4413 - categorical_accuracy: 0.8393
# 51/51 [==============================] - 2s 26ms/step - loss: 0.8467 - categorical_accuracy: 0.7588
# Epoch 1/10
# 457/457 [==============================] - 51s 108ms/step - loss: 1.0229 - categorical_accuracy: 0.6405
# Epoch 2/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.8121 - categorical_accuracy: 0.7191
# Epoch 3/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.7146 - categorical_accuracy: 0.7513
# Epoch 4/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.6559 - categorical_accuracy: 0.7693
# Epoch 5/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.6077 - categorical_accuracy: 0.7844
# Epoch 6/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.5604 - categorical_accuracy: 0.8021
# Epoch 7/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.5217 - categorical_accuracy: 0.8128
# Epoch 8/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.4899 - categorical_accuracy: 0.8241
# Epoch 9/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.4496 - categorical_accuracy: 0.8362
# Epoch 10/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.4219 - categorical_accuracy: 0.8448
# 51/51 [==============================] - 2s 26ms/step - loss: 0.7569 - categorical_accuracy: 0.7655
# Epoch 1/10
# 457/457 [==============================] - 51s 107ms/step - loss: 1.0614 - categorical_accuracy: 0.6219
# Epoch 2/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.8364 - categorical_accuracy: 0.7156
# Epoch 3/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.7510 - categorical_accuracy: 0.7424
# Epoch 4/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.6922 - categorical_accuracy: 0.7641
# Epoch 5/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.6361 - categorical_accuracy: 0.7758
# Epoch 6/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.6028 - categorical_accuracy: 0.7866
# Epoch 7/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.5626 - categorical_accuracy: 0.8043
# Epoch 8/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.5161 - categorical_accuracy: 0.8128
# Epoch 9/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.4875 - categorical_accuracy: 0.8215
# Epoch 10/10
# 457/457 [==============================] - 48s 104ms/step - loss: 0.4687 - categorical_accuracy: 0.8279
# 51/51 [==============================] - 1s 17ms/step - loss: 0.6834 - categorical_accuracy: 0.7655
# Epoch 1/10
# 457/457 [==============================] - 52s 109ms/step - loss: 1.0520 - categorical_accuracy: 0.6274
# Epoch 2/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.8334 - categorical_accuracy: 0.7135
# Epoch 3/10
# 457/457 [==============================] - 48s 106ms/step - loss: 0.7480 - categorical_accuracy: 0.7436
# Epoch 4/10
# 457/457 [==============================] - 46s 101ms/step - loss: 0.6747 - categorical_accuracy: 0.7642
# Epoch 5/10
# 457/457 [==============================] - 47s 102ms/step - loss: 0.6330 - categorical_accuracy: 0.7744
# Epoch 6/10
# 457/457 [==============================] - 49s 108ms/step - loss: 0.5732 - categorical_accuracy: 0.7929
# Epoch 7/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.5455 - categorical_accuracy: 0.8022
# Epoch 8/10
# 457/457 [==============================] - 49s 106ms/step - loss: 0.5032 - categorical_accuracy: 0.8169
# Epoch 9/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.4793 - categorical_accuracy: 0.8274
# Epoch 10/10
# 457/457 [==============================] - 49s 107ms/step - loss: 0.4490 - categorical_accuracy: 0.8345
# 51/51 [==============================] - 2s 26ms/step - loss: 0.7024 - categorical_accuracy: 0.7865
# Epoch 1/10
# 457/457 [==============================] - 52s 109ms/step - loss: 1.0371 - categorical_accuracy: 0.6365
# Epoch 2/10
# 457/457 [==============================] - 50s 109ms/step - loss: 0.8112 - categorical_accuracy: 0.7272
# Epoch 3/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.7192 - categorical_accuracy: 0.7568
# Epoch 4/10
# 457/457 [==============================] - 50s 110ms/step - loss: 0.6610 - categorical_accuracy: 0.7713
# Epoch 5/10
# 457/457 [==============================] - 51s 111ms/step - loss: 0.6114 - categorical_accuracy: 0.7885
# Epoch 6/10
# 457/457 [==============================] - 50s 108ms/step - loss: 0.5644 - categorical_accuracy: 0.8049
# Epoch 7/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.5338 - categorical_accuracy: 0.8138
# Epoch 8/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4996 - categorical_accuracy: 0.8213
# Epoch 9/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4631 - categorical_accuracy: 0.8327
# Epoch 10/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4359 - categorical_accuracy: 0.8421
# 51/51 [==============================] - 1s 16ms/step - loss: 0.8215 - categorical_accuracy: 0.7599
# Epoch 1/10
# 457/457 [==============================] - 32s 68ms/step - loss: 1.0325 - categorical_accuracy: 0.6365
# Epoch 2/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.8287 - categorical_accuracy: 0.7172
# Epoch 3/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.7386 - categorical_accuracy: 0.7475
# Epoch 4/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.6832 - categorical_accuracy: 0.7632
# Epoch 5/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.6250 - categorical_accuracy: 0.7808
# Epoch 6/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5810 - categorical_accuracy: 0.7967
# Epoch 7/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.5395 - categorical_accuracy: 0.8079
# Epoch 8/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.5073 - categorical_accuracy: 0.8202
# Epoch 9/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.4760 - categorical_accuracy: 0.8270
# Epoch 10/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4468 - categorical_accuracy: 0.8395
# 51/51 [==============================] - 1s 16ms/step - loss: 0.7479 - categorical_accuracy: 0.7734
# Epoch 1/10
# 457/457 [==============================] - 33s 70ms/step - loss: 1.0298 - categorical_accuracy: 0.6343
# Epoch 2/10
# 457/457 [==============================] - 31s 69ms/step - loss: 0.8138 - categorical_accuracy: 0.7224
# Epoch 3/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.7280 - categorical_accuracy: 0.7542
# Epoch 4/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.6560 - categorical_accuracy: 0.7746
# Epoch 5/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.6044 - categorical_accuracy: 0.7906
# Epoch 6/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5549 - categorical_accuracy: 0.8053
# Epoch 7/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.5138 - categorical_accuracy: 0.8167
# Epoch 8/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4779 - categorical_accuracy: 0.8293
# Epoch 9/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4497 - categorical_accuracy: 0.8375
# Epoch 10/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.4038 - categorical_accuracy: 0.8560
# 51/51 [==============================] - 1s 16ms/step - loss: 0.7474 - categorical_accuracy: 0.7833
# Epoch 1/10
# 457/457 [==============================] - 32s 69ms/step - loss: 1.0217 - categorical_accuracy: 0.6326
# Epoch 2/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.8274 - categorical_accuracy: 0.7186
# Epoch 3/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.7357 - categorical_accuracy: 0.7517
# Epoch 4/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.6656 - categorical_accuracy: 0.7683
# Epoch 5/10
# 457/457 [==============================] - 30s 67ms/step - loss: 0.6166 - categorical_accuracy: 0.7809
# Epoch 6/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5655 - categorical_accuracy: 0.7991
# Epoch 7/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5297 - categorical_accuracy: 0.8111
# Epoch 8/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4999 - categorical_accuracy: 0.8198
# Epoch 9/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4579 - categorical_accuracy: 0.8328
# Epoch 10/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4406 - categorical_accuracy: 0.8402
# 51/51 [==============================] - 1s 16ms/step - loss: 0.7225 - categorical_accuracy: 0.7796
# Epoch 1/10
# 457/457 [==============================] - 32s 68ms/step - loss: 1.0612 - categorical_accuracy: 0.6204
# Epoch 2/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.8435 - categorical_accuracy: 0.7135
# Epoch 3/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.7562 - categorical_accuracy: 0.7430
# Epoch 4/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.6922 - categorical_accuracy: 0.7594
# Epoch 5/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.6436 - categorical_accuracy: 0.7788
# Epoch 6/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5994 - categorical_accuracy: 0.7891
# Epoch 7/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5554 - categorical_accuracy: 0.8021
# Epoch 8/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.5127 - categorical_accuracy: 0.8159
# Epoch 9/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4881 - categorical_accuracy: 0.8231
# Epoch 10/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4722 - categorical_accuracy: 0.8330
# 51/51 [==============================] - 1s 16ms/step - loss: 0.6946 - categorical_accuracy: 0.7660
# Epoch 1/10
# 457/457 [==============================] - 37s 67ms/step - loss: 1.0268 - categorical_accuracy: 0.6408
# Epoch 2/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.8068 - categorical_accuracy: 0.7251
# Epoch 3/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.7262 - categorical_accuracy: 0.7516
# Epoch 4/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.6510 - categorical_accuracy: 0.7783
# Epoch 5/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.6076 - categorical_accuracy: 0.7902
# Epoch 6/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5565 - categorical_accuracy: 0.8048
# Epoch 7/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.5266 - categorical_accuracy: 0.8142
# Epoch 8/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.4893 - categorical_accuracy: 0.8287
# Epoch 9/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.4529 - categorical_accuracy: 0.8359
# Epoch 10/10
# 457/457 [==============================] - 31s 67ms/step - loss: 0.4299 - categorical_accuracy: 0.8453
# 51/51 [==============================] - 1s 16ms/step - loss: 0.7281 - categorical_accuracy: 0.7943
# Mean validation accuracy over 10-fold cross-validation: 77.33%
# Standard deviation: 1.15%
# 95% confidence interval: (76.62%, 78.04%)

# %%
plt.boxplot(scores[:, 1])
plt.title('Box plot of accuracies over 10-fold cross-validation')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.errorbar(x=[1], y=[mean_score], yerr=[confidence_interval], fmt='o', color='blue', ecolor='red', capsize=5)
plt.title('Mean accuracy with 95% confidence interval')
plt.ylabel('Accuracy')
plt.xticks([])
plt.show()
print(confidence_interval)
# Out:
# 0.007119642353849383

# %% [markdown]
# ## 8 leads

# %%
df_cleaned_8 = df_encoded
# Extract only the first eight leads from every ECG signal
df_cleaned_8['signal'] = df_cleaned_8['signal'].apply(lambda signal: signal[:, :8])

X_8 = df_cleaned_8['signal'].to_numpy()
X_8 = np.array([np.array(x) for x in df_cleaned_8['signal']])

y_8 = df_cleaned_8.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

n_folds_8 = 10
kfold_8 = KFold(n_splits=n_folds_8, shuffle=True, random_state=42)
scores_8 = []

for train_index, val_index in kfold_8.split(X_8):
    X_train_8, X_val_8 = X_8[train_index], X_8[val_index]
    y_train_8, y_val_8 = y_8.iloc[train_index], y_8.iloc[val_index]

    # Define the ECG branch of the model
    ecg_input_8 = layers.Input(shape=(2500, 8))  # Adjust to match the number of leads
    ecg_layer_8 = layers.Conv1D(64, 7, activation='relu')(ecg_input_8)
    ecg_layer_8 = layers.MaxPooling1D(3)(ecg_layer_8)
    ecg_layer_8 = layers.Conv1D(64, 7, activation='relu')(ecg_layer_8)
    ecg_layer_8 = layers.MaxPooling1D(3)(ecg_layer_8)
    ecg_layer_8 = layers.Dropout(0.5)(ecg_layer_8)
    ecg_layer_8 = layers.Flatten()(ecg_layer_8)

    # Add a couple of Dense layers
    output_8 = layers.Dense(64, activation='relu')(ecg_layer_8)
    output_8 = layers.Dropout(0.5)(output_8)
    output_8 = layers.Dense(y_train_8.shape[1], activation='softmax')(output_8)

    model_cnn_8 = tf.keras.Model(inputs=[ecg_input_8], outputs=output_8)
    model_cnn_8.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model_cnn_8.fit(X_train_8, y_train_8, epochs=10)
    score_8 = model_cnn_8.evaluate(X_val_8, y_val_8, verbose=0)  # Set verbose=0 to not print evaluation results
    scores_8.append(score_8)

scores_8 = np.array(scores_8)
mean_score_8 = np.mean(scores_8[:, 1])
std_score_8 = np.std(scores_8[:, 1])

# Compute the 95% confidence interval
confidence_interval_8 = 1.96 * (std_score_8 / np.sqrt(n_folds_8))
lower_bound_8 = mean_score_8 - confidence_interval_8
upper_bound_8 = mean_score_8 + confidence_interval_8

print(f'Mean validation accuracy over {n_folds_8}-fold cross-validation: {mean_score_8 * 100:.2f}%')
print(f'Standard deviation: {std_score_8 * 100:.2f}%')
print(f'95% confidence interval: ({lower_bound_8 * 100:.2f}%, {upper_bound_8 * 100:.2f}%)')

plt.hist(scores_8[:, 1], bins=10)
plt.title(f'Histogram of validation accuracy over {n_folds_8}-fold cross-validation')
plt.xlabel('Validation Accuracy')
plt.ylabel('Count')
plt.show()
# Out:
# Epoch 1/10
# 457/457 [==============================] - 37s 79ms/step - loss: 1.0649 - categorical_accuracy: 0.6324
# Epoch 2/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.8232 - categorical_accuracy: 0.7205
# Epoch 3/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.7472 - categorical_accuracy: 0.7460
# Epoch 4/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6783 - categorical_accuracy: 0.7646
# Epoch 5/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6289 - categorical_accuracy: 0.7846
# Epoch 6/10
# 457/457 [==============================] - 41s 90ms/step - loss: 0.5866 - categorical_accuracy: 0.7936
# Epoch 7/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5454 - categorical_accuracy: 0.8078
# Epoch 8/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5148 - categorical_accuracy: 0.8154
# Epoch 9/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.4901 - categorical_accuracy: 0.8208
# Epoch 10/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.4442 - categorical_accuracy: 0.8361
# Epoch 1/10
# 457/457 [==============================] - 46s 97ms/step - loss: 1.0657 - categorical_accuracy: 0.6160
# Epoch 2/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.8566 - categorical_accuracy: 0.7076
# Epoch 3/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.7572 - categorical_accuracy: 0.7402
# Epoch 4/10
# 457/457 [==============================] - 41s 91ms/step - loss: 0.6879 - categorical_accuracy: 0.7628
# Epoch 5/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.6374 - categorical_accuracy: 0.7783
# Epoch 6/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5912 - categorical_accuracy: 0.7942
# Epoch 7/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5541 - categorical_accuracy: 0.8035
# Epoch 8/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5085 - categorical_accuracy: 0.8177
# Epoch 9/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.4845 - categorical_accuracy: 0.8247
# Epoch 10/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.4446 - categorical_accuracy: 0.8376
# Epoch 1/10
# 457/457 [==============================] - 48s 100ms/step - loss: 1.0593 - categorical_accuracy: 0.6260
# Epoch 2/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.8278 - categorical_accuracy: 0.7161
# Epoch 3/10
# 457/457 [==============================] - 42s 93ms/step - loss: 0.7404 - categorical_accuracy: 0.7495
# Epoch 4/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.6800 - categorical_accuracy: 0.7703
# Epoch 5/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.6263 - categorical_accuracy: 0.7830
# Epoch 6/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5860 - categorical_accuracy: 0.7978
# Epoch 7/10
# 457/457 [==============================] - 43s 93ms/step - loss: 0.5523 - categorical_accuracy: 0.8040
# Epoch 8/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5191 - categorical_accuracy: 0.8152
# Epoch 9/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.4912 - categorical_accuracy: 0.8273
# Epoch 10/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.4541 - categorical_accuracy: 0.8354
# Epoch 1/10
# 457/457 [==============================] - 45s 92ms/step - loss: 1.0668 - categorical_accuracy: 0.6271
# Epoch 2/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.8314 - categorical_accuracy: 0.7166
# Epoch 3/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.7446 - categorical_accuracy: 0.7528
# Epoch 4/10
# 457/457 [==============================] - 46s 101ms/step - loss: 0.6842 - categorical_accuracy: 0.7720
# Epoch 5/10
# 457/457 [==============================] - 47s 102ms/step - loss: 0.6397 - categorical_accuracy: 0.7771
# Epoch 6/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.5936 - categorical_accuracy: 0.7926
# Epoch 7/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5483 - categorical_accuracy: 0.8066
# Epoch 8/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5112 - categorical_accuracy: 0.8189
# Epoch 9/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.4751 - categorical_accuracy: 0.8273
# Epoch 10/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.4534 - categorical_accuracy: 0.8377
# Epoch 1/10
# 457/457 [==============================] - 47s 99ms/step - loss: 1.0436 - categorical_accuracy: 0.6364
# Epoch 2/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.8301 - categorical_accuracy: 0.7181
# Epoch 3/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.7478 - categorical_accuracy: 0.7454
# Epoch 4/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.6836 - categorical_accuracy: 0.7694
# Epoch 5/10
# 457/457 [==============================] - 37s 82ms/step - loss: 0.6494 - categorical_accuracy: 0.7780
# Epoch 6/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.5956 - categorical_accuracy: 0.7903
# Epoch 7/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.5629 - categorical_accuracy: 0.8004
# Epoch 8/10
# 457/457 [==============================] - 44s 95ms/step - loss: 0.5219 - categorical_accuracy: 0.8150
# Epoch 9/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.4938 - categorical_accuracy: 0.8234
# Epoch 10/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.4681 - categorical_accuracy: 0.8333
# Epoch 1/10
# 457/457 [==============================] - 46s 96ms/step - loss: 1.0619 - categorical_accuracy: 0.6212
# Epoch 2/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.8495 - categorical_accuracy: 0.7155
# Epoch 3/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.7717 - categorical_accuracy: 0.7356
# Epoch 4/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.7031 - categorical_accuracy: 0.7562
# Epoch 5/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.6390 - categorical_accuracy: 0.7754
# Epoch 6/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.6011 - categorical_accuracy: 0.7858
# Epoch 7/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.5558 - categorical_accuracy: 0.8004
# Epoch 8/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.5196 - categorical_accuracy: 0.8151
# Epoch 9/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.4872 - categorical_accuracy: 0.8245
# Epoch 10/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.4499 - categorical_accuracy: 0.8353
# Epoch 1/10
# 457/457 [==============================] - 45s 95ms/step - loss: 1.0720 - categorical_accuracy: 0.6233
# Epoch 2/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.8245 - categorical_accuracy: 0.7215
# Epoch 3/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.7329 - categorical_accuracy: 0.7467
# Epoch 4/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.6713 - categorical_accuracy: 0.7674
# Epoch 5/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6153 - categorical_accuracy: 0.7834
# Epoch 6/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.5674 - categorical_accuracy: 0.7977
# Epoch 7/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5306 - categorical_accuracy: 0.8101
# Epoch 8/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.4906 - categorical_accuracy: 0.8235
# Epoch 9/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.4606 - categorical_accuracy: 0.8349
# Epoch 10/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.4319 - categorical_accuracy: 0.8439
# Epoch 1/10
# 457/457 [==============================] - 47s 98ms/step - loss: 1.0444 - categorical_accuracy: 0.6339
# Epoch 2/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.8188 - categorical_accuracy: 0.7218
# Epoch 3/10
# 457/457 [==============================] - 45s 97ms/step - loss: 0.7325 - categorical_accuracy: 0.7499
# Epoch 4/10
# 457/457 [==============================] - 43s 93ms/step - loss: 0.6752 - categorical_accuracy: 0.7694
# Epoch 5/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.6293 - categorical_accuracy: 0.7790
# Epoch 6/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5780 - categorical_accuracy: 0.7955
# Epoch 7/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.5335 - categorical_accuracy: 0.8116
# Epoch 8/10
# 457/457 [==============================] - 43s 93ms/step - loss: 0.5011 - categorical_accuracy: 0.8192
# Epoch 9/10
# 457/457 [==============================] - 47s 103ms/step - loss: 0.4736 - categorical_accuracy: 0.8281
# Epoch 10/10
# 457/457 [==============================] - 47s 102ms/step - loss: 0.4297 - categorical_accuracy: 0.8425
# Epoch 1/10
# 457/457 [==============================] - 47s 98ms/step - loss: 1.0360 - categorical_accuracy: 0.6332
# Epoch 2/10
# 457/457 [==============================] - 42s 93ms/step - loss: 0.8130 - categorical_accuracy: 0.7255
# Epoch 3/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.7251 - categorical_accuracy: 0.7574
# Epoch 4/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.6566 - categorical_accuracy: 0.7731
# Epoch 5/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5975 - categorical_accuracy: 0.7921
# Epoch 6/10
# 457/457 [==============================] - 41s 91ms/step - loss: 0.5509 - categorical_accuracy: 0.8078
# Epoch 7/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5063 - categorical_accuracy: 0.8216
# Epoch 8/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.4670 - categorical_accuracy: 0.8320
# Epoch 9/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.4291 - categorical_accuracy: 0.8445
# Epoch 10/10
# 457/457 [==============================] - 43s 93ms/step - loss: 0.4088 - categorical_accuracy: 0.8511
# Epoch 1/10
# 457/457 [==============================] - 47s 97ms/step - loss: 1.0522 - categorical_accuracy: 0.6328
# Epoch 2/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.8182 - categorical_accuracy: 0.7203
# Epoch 3/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.7433 - categorical_accuracy: 0.7430
# Epoch 4/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.6623 - categorical_accuracy: 0.7713
# Epoch 5/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6145 - categorical_accuracy: 0.7852
# Epoch 6/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5647 - categorical_accuracy: 0.8022
# Epoch 7/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.5216 - categorical_accuracy: 0.8149
# Epoch 8/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.4829 - categorical_accuracy: 0.8262
# Epoch 9/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.4517 - categorical_accuracy: 0.8360
# Epoch 10/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.4258 - categorical_accuracy: 0.8471
# Mean validation accuracy over 10-fold cross-validation: 76.61%
# Standard deviation: 0.77%
# 95% confidence interval: (76.13%, 77.09%)

# %%
plt.boxplot(scores_8[:, 1])
plt.title('Box plot of accuracies over 10-fold cross-validation')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.errorbar(x=[1], y=[mean_score_8], yerr=[confidence_interval_8], fmt='o', color='blue', ecolor='red', capsize=5)
plt.title('Mean accuracy with 95% confidence interval')
plt.ylabel('Accuracy')
plt.xticks([])
plt.show()
print(confidence_interval_8)
# Out:
# 0.004797604200663777

# %% [markdown]
# ## 4 leads

# %%
df_cleaned_4 = df_encoded
# Extract only the first four leads from every ECG signal
df_cleaned_4['signal'] = df_cleaned_4['signal'].apply(lambda signal: signal[:, :4])

X_4 = df_cleaned_4['signal'].to_numpy()
X_4 = np.array([np.array(x) for x in df_cleaned_4['signal']])

y_4 = df_cleaned_4.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

n_folds_4 = 10
kfold_4 = KFold(n_splits=n_folds_4, shuffle=True, random_state=42)
scores_4 = []

for train_index, val_index in kfold_4.split(X_4):
    X_train_4, X_val_4 = X_4[train_index], X_4[val_index]
    y_train_4, y_val_4 = y_4.iloc[train_index], y_4.iloc[val_index]

    # Define the ECG branch of the model
    ecg_input_4 = layers.Input(shape=(2500, 4))  # Adjust to match the number of leads
    ecg_layer_4 = layers.Conv1D(64, 7, activation='relu')(ecg_input_4)
    ecg_layer_4 = layers.MaxPooling1D(3)(ecg_layer_4)
    ecg_layer_4 = layers.Conv1D(64, 7, activation='relu')(ecg_layer_4)
    ecg_layer_4 = layers.MaxPooling1D(3)(ecg_layer_4)
    ecg_layer_4 = layers.Dropout(0.5)(ecg_layer_4)
    ecg_layer_4 = layers.Flatten()(ecg_layer_4)

    # Add a couple of Dense layers
    output_4 = layers.Dense(64, activation='relu')(ecg_layer_4)
    output_4 = layers.Dropout(0.5)(output_4)
    output_4 = layers.Dense(y_train_4.shape[1], activation='softmax')(output_4)

    model_cnn_4 = tf.keras.Model(inputs=[ecg_input_4], outputs=output_4)
    model_cnn_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model_cnn_4.fit(X_train_4, y_train_4, epochs=10)
    score_4 = model_cnn_4.evaluate(X_val_4, y_val_4, verbose=0)  # Set verbose=0 to not print evaluation results
    scores_4.append(score_4)

scores_4 = np.array(scores_4)
mean_score_4 = np.mean(scores_4[:, 1])
std_score_4 = np.std(scores_4[:, 1])

# Compute the 95% confidence interval
confidence_interval_4 = 1.96 * (std_score_4 / np.sqrt(n_folds_4))
lower_bound_4 = mean_score_4 - confidence_interval_4
upper_bound_4 = mean_score_4 + confidence_interval_4

print(f'Mean validation accuracy over {n_folds_4}-fold cross-validation: {mean_score_4 * 100:.2f}%')
print(f'Standard deviation: {std_score_4 * 100:.2f}%')
print(f'95% confidence interval: ({lower_bound_4 * 100:.2f}%, {upper_bound_4 * 100:.2f}%)')

plt.hist(scores_4[:, 1], bins=10)
plt.title(f'Histogram of validation accuracy over {n_folds_4}-fold cross-validation')
plt.xlabel('Validation Accuracy')
plt.ylabel('Count')
plt.show()
# Out:
# Epoch 1/10
# 457/457 [==============================] - 47s 98ms/step - loss: 1.1092 - categorical_accuracy: 0.6091
# Epoch 2/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.8872 - categorical_accuracy: 0.6935
# Epoch 3/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.8068 - categorical_accuracy: 0.7213
# Epoch 4/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.7509 - categorical_accuracy: 0.7436
# Epoch 5/10
# 457/457 [==============================] - 42s 93ms/step - loss: 0.6926 - categorical_accuracy: 0.7607
# Epoch 6/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6419 - categorical_accuracy: 0.7737
# Epoch 7/10
# 457/457 [==============================] - 44s 95ms/step - loss: 0.6072 - categorical_accuracy: 0.7873
# Epoch 8/10
# 457/457 [==============================] - 45s 97ms/step - loss: 0.5660 - categorical_accuracy: 0.7981
# Epoch 9/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.5320 - categorical_accuracy: 0.8085
# Epoch 10/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.5058 - categorical_accuracy: 0.8217
# Epoch 1/10
# 457/457 [==============================] - 47s 98ms/step - loss: 1.1419 - categorical_accuracy: 0.5988
# Epoch 2/10
# 457/457 [==============================] - 52s 115ms/step - loss: 0.9250 - categorical_accuracy: 0.6776
# Epoch 3/10
# 457/457 [==============================] - 41s 90ms/step - loss: 0.8205 - categorical_accuracy: 0.7164
# Epoch 4/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.7509 - categorical_accuracy: 0.7417
# Epoch 5/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.7060 - categorical_accuracy: 0.7559
# Epoch 6/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.6614 - categorical_accuracy: 0.7668
# Epoch 7/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.6289 - categorical_accuracy: 0.7790
# Epoch 8/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.5840 - categorical_accuracy: 0.7914
# Epoch 9/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.5546 - categorical_accuracy: 0.8005
# Epoch 10/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.5189 - categorical_accuracy: 0.8107
# Epoch 1/10
# 457/457 [==============================] - 46s 95ms/step - loss: 1.1301 - categorical_accuracy: 0.5888
# Epoch 2/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.9296 - categorical_accuracy: 0.6781
# Epoch 3/10
# 457/457 [==============================] - 46s 101ms/step - loss: 0.8270 - categorical_accuracy: 0.7123
# Epoch 4/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.7539 - categorical_accuracy: 0.7416
# Epoch 5/10
# 457/457 [==============================] - 41s 91ms/step - loss: 0.7100 - categorical_accuracy: 0.7547
# Epoch 6/10
# 457/457 [==============================] - 37s 82ms/step - loss: 0.6718 - categorical_accuracy: 0.7654
# Epoch 7/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6297 - categorical_accuracy: 0.7760
# Epoch 8/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.5961 - categorical_accuracy: 0.7834
# Epoch 9/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.5610 - categorical_accuracy: 0.7988
# Epoch 10/10
# 457/457 [==============================] - 40s 88ms/step - loss: 0.5240 - categorical_accuracy: 0.8094
# Epoch 1/10
# 457/457 [==============================] - 44s 92ms/step - loss: 1.1717 - categorical_accuracy: 0.5697
# Epoch 2/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.9657 - categorical_accuracy: 0.6574
# Epoch 3/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.8464 - categorical_accuracy: 0.7011
# Epoch 4/10
# 457/457 [==============================] - 40s 88ms/step - loss: 0.7846 - categorical_accuracy: 0.7295
# Epoch 5/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.7383 - categorical_accuracy: 0.7461
# Epoch 6/10
# 457/457 [==============================] - 41s 89ms/step - loss: 0.7009 - categorical_accuracy: 0.7565
# Epoch 7/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6592 - categorical_accuracy: 0.7661
# Epoch 8/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6219 - categorical_accuracy: 0.7810
# Epoch 9/10
# 457/457 [==============================] - 40s 89ms/step - loss: 0.5834 - categorical_accuracy: 0.7908
# Epoch 10/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.5600 - categorical_accuracy: 0.7972
# Epoch 1/10
# 457/457 [==============================] - 44s 91ms/step - loss: 1.1184 - categorical_accuracy: 0.6075
# Epoch 2/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.9002 - categorical_accuracy: 0.6906
# Epoch 3/10
# 457/457 [==============================] - 41s 89ms/step - loss: 0.8061 - categorical_accuracy: 0.7209
# Epoch 4/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.7425 - categorical_accuracy: 0.7432
# Epoch 5/10
# 457/457 [==============================] - 42s 91ms/step - loss: 0.7010 - categorical_accuracy: 0.7597
# Epoch 6/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6550 - categorical_accuracy: 0.7690
# Epoch 7/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.6117 - categorical_accuracy: 0.7826
# Epoch 8/10
# 457/457 [==============================] - 44s 95ms/step - loss: 0.5807 - categorical_accuracy: 0.7910
# Epoch 9/10
# 457/457 [==============================] - 43s 93ms/step - loss: 0.5429 - categorical_accuracy: 0.8080
# Epoch 10/10
# 457/457 [==============================] - 44s 95ms/step - loss: 0.5240 - categorical_accuracy: 0.8127
# Epoch 1/10
# 457/457 [==============================] - 45s 93ms/step - loss: 1.1739 - categorical_accuracy: 0.5711
# Epoch 2/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.9742 - categorical_accuracy: 0.6551
# Epoch 3/10
# 457/457 [==============================] - 43s 95ms/step - loss: 0.8683 - categorical_accuracy: 0.6982
# Epoch 4/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.8095 - categorical_accuracy: 0.7196
# Epoch 5/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.7636 - categorical_accuracy: 0.7329
# Epoch 6/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.7255 - categorical_accuracy: 0.7473
# Epoch 7/10
# 457/457 [==============================] - 44s 97ms/step - loss: 0.6836 - categorical_accuracy: 0.7570
# Epoch 8/10
# 457/457 [==============================] - 43s 94ms/step - loss: 0.6551 - categorical_accuracy: 0.7689
# Epoch 9/10
# 457/457 [==============================] - 45s 98ms/step - loss: 0.6209 - categorical_accuracy: 0.7788
# Epoch 10/10
# 457/457 [==============================] - 42s 93ms/step - loss: 0.5956 - categorical_accuracy: 0.7856
# Epoch 1/10
# 457/457 [==============================] - 47s 98ms/step - loss: 1.1357 - categorical_accuracy: 0.5899
# Epoch 2/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.9324 - categorical_accuracy: 0.6788
# Epoch 3/10
# 457/457 [==============================] - 45s 99ms/step - loss: 0.8458 - categorical_accuracy: 0.7058
# Epoch 4/10
# 457/457 [==============================] - 42s 92ms/step - loss: 0.7840 - categorical_accuracy: 0.7291
# Epoch 5/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.7360 - categorical_accuracy: 0.7441
# Epoch 6/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6904 - categorical_accuracy: 0.7571
# Epoch 7/10
# 457/457 [==============================] - 44s 96ms/step - loss: 0.6514 - categorical_accuracy: 0.7715
# Epoch 8/10
# 457/457 [==============================] - 41s 89ms/step - loss: 0.6125 - categorical_accuracy: 0.7843
# Epoch 9/10
# 457/457 [==============================] - 31s 68ms/step - loss: 0.5837 - categorical_accuracy: 0.7939
# Epoch 10/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5429 - categorical_accuracy: 0.8033
# Epoch 1/10
# 457/457 [==============================] - 28s 60ms/step - loss: 1.1376 - categorical_accuracy: 0.5917
# Epoch 2/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.9366 - categorical_accuracy: 0.6807
# Epoch 3/10
# 457/457 [==============================] - 28s 60ms/step - loss: 0.8240 - categorical_accuracy: 0.7126
# Epoch 4/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.7693 - categorical_accuracy: 0.7300
# Epoch 5/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.7197 - categorical_accuracy: 0.7460
# Epoch 6/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.6777 - categorical_accuracy: 0.7635
# Epoch 7/10
# 457/457 [==============================] - 29s 63ms/step - loss: 0.6472 - categorical_accuracy: 0.7695
# Epoch 8/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.6096 - categorical_accuracy: 0.7792
# Epoch 9/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5715 - categorical_accuracy: 0.7914
# Epoch 10/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5492 - categorical_accuracy: 0.7997
# Epoch 1/10
# 457/457 [==============================] - 30s 65ms/step - loss: 1.1758 - categorical_accuracy: 0.5845
# Epoch 2/10
# 457/457 [==============================] - 29s 64ms/step - loss: 0.9337 - categorical_accuracy: 0.6744
# Epoch 3/10
# 457/457 [==============================] - 29s 62ms/step - loss: 0.8137 - categorical_accuracy: 0.7233
# Epoch 4/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.7639 - categorical_accuracy: 0.7369
# Epoch 5/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.7078 - categorical_accuracy: 0.7589
# Epoch 6/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.6624 - categorical_accuracy: 0.7677
# Epoch 7/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.6164 - categorical_accuracy: 0.7819
# Epoch 8/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5839 - categorical_accuracy: 0.7917
# Epoch 9/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.5577 - categorical_accuracy: 0.7981
# Epoch 10/10
# 457/457 [==============================] - 29s 63ms/step - loss: 0.5200 - categorical_accuracy: 0.8123
# Epoch 1/10
# 457/457 [==============================] - 28s 61ms/step - loss: 1.1741 - categorical_accuracy: 0.5720
# Epoch 2/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.9530 - categorical_accuracy: 0.6666
# Epoch 3/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.8418 - categorical_accuracy: 0.7103
# Epoch 4/10
# 457/457 [==============================] - 28s 60ms/step - loss: 0.7688 - categorical_accuracy: 0.7365
# Epoch 5/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.7218 - categorical_accuracy: 0.7457
# Epoch 6/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.6853 - categorical_accuracy: 0.7644
# Epoch 7/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.6443 - categorical_accuracy: 0.7735
# Epoch 8/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.5980 - categorical_accuracy: 0.7871
# Epoch 9/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5680 - categorical_accuracy: 0.7980
# Epoch 10/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.5426 - categorical_accuracy: 0.8064
# Mean validation accuracy over 10-fold cross-validation: 73.38%
# Standard deviation: 1.11%
# 95% confidence interval: (72.69%, 74.07%)

# %%
plt.boxplot(scores_4[:, 1])
plt.title('Box plot of accuracies over 10-fold cross-validation')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.errorbar(x=[1], y=[mean_score_4], yerr=[confidence_interval_4], fmt='o', color='blue', ecolor='red', capsize=5)
plt.title('Mean accuracy with 95% confidence interval')
plt.ylabel('Accuracy')
plt.xticks([])
plt.show()
print(confidence_interval_4)
# Out:
# 0.006910826671650567

# %% [markdown]
# ## 2 lead (II)

# %%
df_cleaned_2 = df_encoded
# Extract only the first two leads from every ECG signal
df_cleaned_2['signal'] = df_cleaned_2['signal'].apply(lambda signal: signal[:, :2])

X_2 = df_cleaned_2['signal'].to_numpy()
X_2 = np.array([np.array(x) for x in df_cleaned_2['signal']])

y_2 = df_cleaned_2.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

n_folds_2 = 10
kfold_2 = KFold(n_splits=n_folds_2, shuffle=True, random_state=42)
scores_2 = []

for train_index, val_index in kfold_2.split(X_2):
    X_train_2, X_val_2 = X_2[train_index], X_2[val_index]
    y_train_2, y_val_2 = y_2.iloc[train_index], y_2.iloc[val_index]

    # Define the ECG branch of the model
    ecg_input_2 = layers.Input(shape=(2500, 2))
    ecg_layer_2 = layers.Conv1D(64, 7, activation='relu')(ecg_input_2)
    ecg_layer_2 = layers.MaxPooling1D(3)(ecg_layer_2)
    ecg_layer_2 = layers.Conv1D(64, 7, activation='relu')(ecg_layer_2)
    ecg_layer_2 = layers.MaxPooling1D(3)(ecg_layer_2)
    ecg_layer_2 = layers.Dropout(0.5)(ecg_layer_2)
    ecg_layer_2 = layers.Flatten()(ecg_layer_2)

    # Add a couple of Dense layers
    output_2 = layers.Dense(64, activation='relu')(ecg_layer_2)
    output_2 = layers.Dropout(0.5)(output_2)
    output_2 = layers.Dense(y_train_2.shape[1], activation='softmax')(output_2)

    model_cnn_2 = tf.keras.Model(inputs=[ecg_input_2], outputs=output_2)
    model_cnn_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model_cnn_2.fit(X_train_2, y_train_2, epochs=10)
    score_2 = model_cnn_2.evaluate(X_val_2, y_val_2, verbose=0)
    scores_2.append(score_2)

scores_2 = np.array(scores_2)
mean_score_2 = np.mean(scores_2[:, 1])
std_score_2 = np.std(scores_2[:, 1])

# Compute the 95% confidence interval
confidence_interval_2 = 1.96 * (std_score_2 / np.sqrt(n_folds_2))
lower_bound_2 = mean_score_2 - confidence_interval_2
upper_bound_2 = mean_score_2 + confidence_interval_2

print(f'Mean validation accuracy over {n_folds_2}-fold cross-validation: {mean_score_2 * 100:.2f}%')
print(f'Standard deviation: {std_score_2 * 100:.2f}%')
print(f'95% confidence interval: ({lower_bound_2 * 100:.2f}%, {upper_bound_2 * 100:.2f}%)')

plt.hist(scores_2[:, 1], bins=10)
plt.title(f'Histogram of validation accuracy over {n_folds_2}-fold cross-validation')
plt.xlabel('Validation Accuracy')
plt.ylabel('Count')
plt.show()
# Out:
# Epoch 1/10
# 457/457 [==============================] - 27s 58ms/step - loss: 1.1366 - categorical_accuracy: 0.5959
# Epoch 2/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.9241 - categorical_accuracy: 0.6734
# Epoch 3/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.8301 - categorical_accuracy: 0.7111
# Epoch 4/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.7652 - categorical_accuracy: 0.7327
# Epoch 5/10
# 457/457 [==============================] - 26s 56ms/step - loss: 0.7277 - categorical_accuracy: 0.7481
# Epoch 6/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.6804 - categorical_accuracy: 0.7554
# Epoch 7/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.6411 - categorical_accuracy: 0.7760
# Epoch 8/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.6210 - categorical_accuracy: 0.7776
# Epoch 9/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5834 - categorical_accuracy: 0.7895
# Epoch 10/10
# 457/457 [==============================] - 26s 56ms/step - loss: 0.5574 - categorical_accuracy: 0.7987

# %%
plt.errorbar(x=[1], y=[mean_score_2], yerr=[confidence_interval_2], fmt='o', color='blue', ecolor='red', capsize=5)
plt.title('Mean accuracy with 95% confidence interval')
plt.ylabel('Accuracy')
plt.xticks([])
plt.show()
print(confidence_interval_2)
# Out:
# 0.0062982891676095385

# %%
plt.boxplot(scores_2[:, 1])
plt.title('Box plot of accuracies over 10-fold cross-validation')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ## 1 lead (II)

# %%
df_cleaned_1 = df_encoded
# Extract only the first lead from every ECG signal
df_cleaned_1['signal'] = df_cleaned_1['signal'].apply(lambda signal: signal[:, :1])

X_1 = df_cleaned_1['signal'].to_numpy()
X_1 = np.array([np.array(x) for x in df_cleaned_1['signal']])

y_1 = df_cleaned_1.drop(['record_name', 'signal', 'age', 'sex'], axis=1)

n_folds_1 = 10
kfold_1 = KFold(n_splits=n_folds_1, shuffle=True, random_state=42)
scores_1 = []

for train_index, val_index in kfold_1.split(X_1):
    X_train_1, X_val_1 = X_1[train_index], X_1[val_index]
    y_train_1, y_val_1 = y_1.iloc[train_index], y_1.iloc[val_index]

    # Define the ECG branch of the model
    ecg_input_1 = layers.Input(shape=(2500, 1))
    ecg_layer_1 = layers.Conv1D(64, 7, activation='relu')(ecg_input_1)
    ecg_layer_1 = layers.MaxPooling1D(3)(ecg_layer_1)
    ecg_layer_1 = layers.Conv1D(64, 7, activation='relu')(ecg_layer_1)
    ecg_layer_1 = layers.MaxPooling1D(3)(ecg_layer_1)
    ecg_layer_1 = layers.Dropout(0.5)(ecg_layer_1)
    ecg_layer_1 = layers.Flatten()(ecg_layer_1)

    # Add a couple of Dense layers
    output_1 = layers.Dense(64, activation='relu')(ecg_layer_1)
    output_1 = layers.Dropout(0.5)(output_1)
    output_1 = layers.Dense(y_train_1.shape[1], activation='softmax')(output_1)

    model_cnn_1 = tf.keras.Model(inputs=[ecg_input_1], outputs=output_1)
    model_cnn_1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

    model_cnn_1.fit(X_train_1, y_train_1, epochs=10)
    score_1 = model_cnn_1.evaluate(X_val_1, y_val_1, verbose=0)
    scores_1.append(score_1)

scores_1 = np.array(scores_1)
mean_score_1 = np.mean(scores_1[:, 1])
std_score_1 = np.std(scores_1[:, 1])

# Compute the 95% confidence interval
confidence_interval_1 = 1.96 * (std_score_1 / np.sqrt(n_folds_1))
lower_bound_1 = mean_score_1 - confidence_interval_1
upper_bound_1 = mean_score_1 + confidence_interval_1

print(f'Mean validation accuracy over {n_folds_1}-fold cross-validation: {mean_score_1 * 100:.2f}%')
print(f'Standard deviation: {std_score_1 * 100:.2f}%')
print(f'95% confidence interval: ({lower_bound_1 * 100:.2f}%, {upper_bound_1 * 100:.2f}%)')

plt.hist(scores_1[:, 1], bins=10)
plt.title(f'Histogram of validation accuracy over {n_folds_1}-fold cross-validation')
plt.xlabel('Validation Accuracy')
plt.ylabel('Count')
plt.show()
# Out:
# Epoch 1/10
# 457/457 [==============================] - 27s 57ms/step - loss: 0.6625 - accuracy: 0.6095
# Epoch 2/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5843 - accuracy: 0.7143
# Epoch 3/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5574 - accuracy: 0.7283
# Epoch 4/10
# 457/457 [==============================] - 26s 56ms/step - loss: 0.5407 - accuracy: 0.7384
# Epoch 5/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5260 - accuracy: 0.7507
# Epoch 6/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5141 - accuracy: 0.7531
# Epoch 7/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5044 - accuracy: 0.7624
# Epoch 8/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.4923 - accuracy: 0.7690
# Epoch 9/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.4800 - accuracy: 0.7732
# Epoch 10/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.4624 - accuracy: 0.7849
# Epoch 1/10
# 457/457 [==============================] - 27s 57ms/step - loss: 0.6702 - accuracy: 0.5933
# Epoch 2/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5861 - accuracy: 0.7092
# Epoch 3/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5661 - accuracy: 0.7251
# Epoch 4/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5489 - accuracy: 0.7364
# Epoch 5/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5276 - accuracy: 0.7416
# Epoch 6/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5133 - accuracy: 0.7512
# Epoch 7/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5065 - accuracy: 0.7574
# Epoch 8/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.4923 - accuracy: 0.7635
# Epoch 9/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.4758 - accuracy: 0.7760
# Epoch 10/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.4669 - accuracy: 0.7789
# Epoch 1/10
# 457/457 [==============================] - 28s 59ms/step - loss: 0.6526 - accuracy: 0.6235
# Epoch 2/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5806 - accuracy: 0.7194
# Epoch 3/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5575 - accuracy: 0.7312
# Epoch 4/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5345 - accuracy: 0.7423
# Epoch 5/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5264 - accuracy: 0.7466
# Epoch 6/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5056 - accuracy: 0.7581
# Epoch 7/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5063 - accuracy: 0.7553
# Epoch 8/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.4934 - accuracy: 0.7646
# Epoch 9/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.4850 - accuracy: 0.7698
# Epoch 10/10
# 457/457 [==============================] - 26s 56ms/step - loss: 0.4751 - accuracy: 0.7774
# Epoch 1/10
# 457/457 [==============================] - 27s 57ms/step - loss: 0.6702 - accuracy: 0.5914
# Epoch 2/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5998 - accuracy: 0.6846
# Epoch 3/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5608 - accuracy: 0.7220
# Epoch 4/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5380 - accuracy: 0.7364
# Epoch 5/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5209 - accuracy: 0.7462
# Epoch 6/10
# 457/457 [==============================] - 28s 60ms/step - loss: 0.5052 - accuracy: 0.7558
# Epoch 7/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.4932 - accuracy: 0.7650
# Epoch 8/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.4818 - accuracy: 0.7676
# Epoch 9/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.4729 - accuracy: 0.7769
# Epoch 10/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.4593 - accuracy: 0.7871
# Epoch 1/10
# 457/457 [==============================] - 29s 62ms/step - loss: 0.6625 - accuracy: 0.5989
# Epoch 2/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5999 - accuracy: 0.6989
# Epoch 3/10
# 457/457 [==============================] - 28s 62ms/step - loss: 0.5710 - accuracy: 0.7194
# Epoch 4/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5505 - accuracy: 0.7287
# Epoch 5/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5417 - accuracy: 0.7385
# Epoch 6/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5283 - accuracy: 0.7448
# Epoch 7/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5185 - accuracy: 0.7523
# Epoch 8/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.5034 - accuracy: 0.7568
# Epoch 9/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.4998 - accuracy: 0.7611
# Epoch 10/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.4891 - accuracy: 0.7712
# Epoch 1/10
# 457/457 [==============================] - 28s 59ms/step - loss: 0.6621 - accuracy: 0.6064
# Epoch 2/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5847 - accuracy: 0.7120
# Epoch 3/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5555 - accuracy: 0.7303
# Epoch 4/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5440 - accuracy: 0.7339
# Epoch 5/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5309 - accuracy: 0.7428
# Epoch 6/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5222 - accuracy: 0.7518
# Epoch 7/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5110 - accuracy: 0.7536
# Epoch 8/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5055 - accuracy: 0.7630
# Epoch 9/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.4986 - accuracy: 0.7637
# Epoch 10/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.4894 - accuracy: 0.7678
# Epoch 1/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.6617 - accuracy: 0.5978
# Epoch 2/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5905 - accuracy: 0.7088
# Epoch 3/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.5645 - accuracy: 0.7222
# Epoch 4/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5421 - accuracy: 0.7354
# Epoch 5/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5351 - accuracy: 0.7402
# Epoch 6/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5217 - accuracy: 0.7460
# Epoch 7/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.5079 - accuracy: 0.7559
# Epoch 8/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5001 - accuracy: 0.7610
# Epoch 9/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.4907 - accuracy: 0.7702
# Epoch 10/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.4821 - accuracy: 0.7715
# Epoch 1/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.6549 - accuracy: 0.6150
# Epoch 2/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5818 - accuracy: 0.7133
# Epoch 3/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5591 - accuracy: 0.7254
# Epoch 4/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5423 - accuracy: 0.7335
# Epoch 5/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5302 - accuracy: 0.7419
# Epoch 6/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5198 - accuracy: 0.7505
# Epoch 7/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5145 - accuracy: 0.7538
# Epoch 8/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5022 - accuracy: 0.7587
# Epoch 9/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.4875 - accuracy: 0.7694
# Epoch 10/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.4887 - accuracy: 0.7694
# Epoch 1/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.6624 - accuracy: 0.6027
# Epoch 2/10
# 457/457 [==============================] - 28s 60ms/step - loss: 0.6095 - accuracy: 0.7041
# Epoch 3/10
# 457/457 [==============================] - 27s 58ms/step - loss: 0.5610 - accuracy: 0.7256
# Epoch 4/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5492 - accuracy: 0.7323
# Epoch 5/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5391 - accuracy: 0.7389
# Epoch 6/10
# 457/457 [==============================] - 26s 58ms/step - loss: 0.5256 - accuracy: 0.7488
# Epoch 7/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5195 - accuracy: 0.7501
# Epoch 8/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5128 - accuracy: 0.7516
# Epoch 9/10
# 457/457 [==============================] - 26s 57ms/step - loss: 0.5053 - accuracy: 0.7584
# Epoch 10/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.5041 - accuracy: 0.7598
# Epoch 1/10
# 457/457 [==============================] - 27s 57ms/step - loss: 0.6707 - accuracy: 0.5959
# Epoch 2/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5991 - accuracy: 0.6923
# Epoch 3/10
# 457/457 [==============================] - 28s 61ms/step - loss: 0.5755 - accuracy: 0.7177
# Epoch 4/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5575 - accuracy: 0.7269
# Epoch 5/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5436 - accuracy: 0.7354
# Epoch 6/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5330 - accuracy: 0.7384
# Epoch 7/10
# 457/457 [==============================] - 27s 60ms/step - loss: 0.5280 - accuracy: 0.7481
# Epoch 8/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5171 - accuracy: 0.7519
# Epoch 9/10
# 457/457 [==============================] - 28s 60ms/step - loss: 0.5104 - accuracy: 0.7556
# Epoch 10/10
# 457/457 [==============================] - 27s 59ms/step - loss: 0.5054 - accuracy: 0.7581
# Mean validation accuracy over 10-fold cross-validation: 73.81%
# Standard deviation: 1.19%
# 95% confidence interval: (73.07%, 74.55%)

# %%
plt.errorbar(x=[1], y=[mean_score_1], yerr=[confidence_interval_1], fmt='o', color='blue', ecolor='red', capsize=5)
plt.title('Mean accuracy with 95% confidence interval')
plt.ylabel('Accuracy')
plt.xticks([])
plt.show()
print(confidence_interval_1)
# Out:
# 0.007403728483878864

# %%
plt.boxplot(scores_1[:, 1])
plt.title('Box plot of accuracies over 10-fold cross-validation')
plt.ylabel('Accuracy')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extracting just the accuracies (assuming they are the second value in each list)
accuracies_1 = [s[1] for s in scores_1]
accuracies_2 = [s[1] for s in scores_2]
accuracies_4 = [s[1] for s in scores_4]
accuracies_8 = [s[1] for s in scores_8]
accuracies_12 = [s[1] for s in scores]

data = {
    '1-lead': accuracies_1,
    '2-lead': accuracies_2,
    '4-lead': accuracies_4,
    '8-lead': accuracies_8,
    '12-lead': accuracies_12
}

# Convert the dictionary to a format suitable for seaborn
labels, values = [], []
for k, v in data.items():
    labels.extend([k] * len(v))
    values.extend(v)

# Create a DataFrame
import pandas as pd
df = pd.DataFrame({'Lead Configuration': labels, 'Accuracy': values})

# Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Lead Configuration', y='Accuracy', data=df, order=['1-lead', '2-lead', '4-lead', '8-lead', '12-lead'])
plt.title('Boxplots of Accuracies for Each Lead Configuration')
plt.show()

# %%
means = [0.7381206512451172, 0.8033743023872375, 0.8016502439975739, 0.815009206533432, 0.8328012943267822]  # Replace with your mean accuracies for each lead
stds = [0.011945227135980835, 0.010161703638781706, 0.008436370107625142, 0.006801869683438827, 0.006808356009703941]
leads = ['1-lead', '2-lead', '4-lead', '8-lead', '12-lead']

plt.figure(figsize=(10, 6))
sns.barplot(x=leads, y=means, yerr=stds, capsize=0.1, palette="Blues_d")
plt.title('Mean Accuracy with Standard Deviation for Each Lead Configuration')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Lead Configuration', y='Accuracy', data=df, order=leads, palette="Blues_d")
plt.title('Violin Plot of Accuracies for Each Lead Configuration')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Lead Configuration', y='Accuracy', data=df, order=leads, palette="Blues_d")
plt.title('Swarm Plot of Accuracies for Each Lead Configuration')
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_25476\2178098963.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Lead Configuration', y='Accuracy', data=df, order=leads, palette="Blues_d")

# %%
# Sample data (replace with your actual data)

leads = ['1-lead', '2-lead', '4-lead', '8-lead', '12-lead']

# Calculate the 95% CI for each lead configuration
n = 10  # Number of folds in cross-validation
ci_upper = [mean + 1.96 * (std / np.sqrt(n)) for mean, std in zip(means, stds)]
ci_lower = [mean - 1.96 * (std / np.sqrt(n)) for mean, std in zip(means, stds)]

plt.figure(figsize=(10, 6))
sns.barplot(x=leads, y=means, yerr=[means - np.array(ci_lower), np.array(ci_upper) - means], capsize=0.1, palette="Blues_d")
plt.title('Mean Accuracy with 95% Confidence Interval for Each Lead Configuration')
plt.ylabel('Accuracy')
plt.show()

# Print the results in a format suitable for LaTeX tables
print("\\begin{tabular}{|c|c|}")
print("\\hline")
print("Lead Configuration & 95% Confidence Interval \\\\")
print("\\hline")
for lead, lower, upper in zip(leads, ci_lower, ci_upper):
    print(f"{lead} & ({lower:.2f}, {upper:.2f}) \\\\")
    print("\\hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{|c|c|}
# \hline
# Lead Configuration & 95% Confidence Interval \\
# \hline
# 1-lead & (0.73, 0.75) \\
# \hline
# 2-lead & (0.80, 0.81) \\
# \hline
# 4-lead & (0.80, 0.81) \\
# \hline
# 8-lead & (0.81, 0.82) \\
# \hline
# 12-lead & (0.83, 0.84) \\
# \hline
# \end{tabular}

# %% [markdown]
# todo:
#  - complete preprocessing -> normalization, Noise Reduction, Outlier Removal,Data Augmentation,downsampling, invert?
#  - convert signal to spectogram 2D? (not 1D CNN raw data anymore, can be generated with STFT, 2D CNN) 1D simpler but 2D may perform better
#  - remove diseases because accuracy is poor
#  - rajouter age et sexe?
#  - CNN prep, build, model train, evaluate
#  - RNN
#  - Transofrmer
#
# - checker la normalisation
# - passer en 250 sample rate

# %% [markdown]
# Done:
# - remove last beat (when 0 volt)
